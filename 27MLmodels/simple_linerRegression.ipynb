# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
import sys
# !{sys.executable} -m pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
df = pd.read_csv("height-weight.csv")

# %%
df.head()
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123
# 3      60     145
# 4      70     160

# %%
plt.scatter(df["Height"], df["Weight"])
plt.ylabel("Height")
plt.xlabel("Weight")
plt.title("Height vs Weight")
# Out:
# Text(0.5, 1.0, 'Height vs Weight')

# %%
# corelation
df.corr()
# Out:
#           Weight    Height
# Weight  1.000000  0.931142
# Height  0.931142  1.000000

# %%
# %pip install seaborn

import seaborn as sns
sns.pairplot(df)
# Out:
# Requirement already satisfied: seaborn in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from seaborn) (2.4.3)
# Requirement already satisfied: pandas>=1.2 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from seaborn) (3.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from seaborn) (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (26.0)
# Requirement already satisfied: pillow>=8 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/isha/Documents/NLP/.venv/lib/python3.14/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
X = df['Weight']
X
# type(X)
# Out:
# 0      45
# 1      58
# 2      48
# 3      60
# 4      70
# 5      78
# 6      80
# 7      90
# 8      95
# 9      78
# 10     82
# 11     95
# 12    105
# 13    100
# 14     85
# 15     78
# 16     50
# 17     65
# 18     76
# 19     87
# 20     45
# 21     56
# 22     72
# Name: Weight, dtype: int64

# %%
type(X)
# Out:
# pandas.Series

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
X = df[['Weight']]
X
# Out:
#     Weight
# 0       45
# 1       58
# 2       48
# 3       60
# 4       70
# 5       78
# 6       80
# 7       90
# 8       95
# 9       78
# 10      82
# 11      95
# 12     105
# 13     100
# 14      85
# 15      78
# 16      50
# 17      65
# 18      76
# 19      87
# 20      45
# 21      56
# 22      72

# %%
np.array(X).shape
# Out:
# (23, 1)

# %%
X = df["Weight"]
np.array(X).shape
# Out:
# (23,)

# %%
X = df[['Weight']]
Y = df["Height"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
X_train.shape
# Out:
# (17, 1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_test
# Out:
# array([[ 0.33497168],
#        [ 0.33497168],
#        [-1.6641678 ],
#        [ 1.36483141],
#        [-0.45256812],
#        [ 1.97063125]])

# %%
# Apply simple lenear transformation
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()
