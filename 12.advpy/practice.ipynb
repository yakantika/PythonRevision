# %%
def square(x):
    for i in range(3):
        return i ** 2

# %%
square(5)
# Out:
# 0

# %%
def square(n):
    for i in range(n):
        yield i ** 2

# %%
square(5)
# Out:
# <generator object square at 0x103e0ec20>

# %%
for i in square(5):
    print(i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
a = square(2)

# %%
next(a)
# Out:
# 0

# %%
next(a)
# Out:
# 1

# %%
next(a)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 next(a)
#
# StopIteration:
