# %%
for i in range(0,4):
    print("****")
# Out:
# ****
# ****
# ****
# ****

# %%
n = int(input(""))
for i in range(0, n):
    for j in range(0,n):
        print("*", end=(""))
    # print("\n")
    print()
# Out:
# ****
# ****
# ****
# ****
